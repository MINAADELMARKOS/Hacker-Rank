# %% [markdown]
# # THANOS PROJECT

# %%
from IPython.display import Image
Image(filename=r'C:\Users\Mina\Desktop\22.jpg')

# %%
import os 
import random
import math 
import time

# %%
def show_add_uni(place):
    people=os.listdir(r"C:\Users\Mina\Desktop\thanos")
    return people
    
people=show_add_uni(r"C:\Users\Mina\Desktop\thanos")

# %%
for i in range(len(people)//2):
    curr_vic=random.choice(people)
    os.remove(r"C:\Users\Mina\Desktop\thanos" + '/' + curr_vic)
    people.remove(curr_vic)
    print(curr_vic)
